# %% [markdown]
# # Answer example: Day2 Class assignment 2 Problem of going down Mt. Fuji

# %% [markdown]
# ## Problem of going down Mt. Fuji
#
# Gradient descent is likened to going down a mountain or valley. You will learn the gradient descent method by creating a descent program from Mt. Fuji, using the elevation data of Mt. Fuji as an objective function ** that you want to minimize.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %%
csv_path = "mtfuji_data.csv" # Specify the file name (path)

np.set_printoptions(suppress=True) # Set the prohibition of exponential notation

fuji = np.loadtxt(csv_path, delimiter=",", skiprows=1)

# %%
print("View part of the elevation dataset\n{}".format(fuji[130:140]))
# Out:
# View part of the elevation dataset
# [[  130.          35.352505   138.756638  2563.4      41888.      ]
#  [  131.          35.35418    138.753742  2703.1      42210.      ]
#  [  132.          35.355855   138.750846  2825.55     42532.      ]
#  [  133.          35.35753    138.74795   2967.9      42854.      ]
#  [  134.          35.359205   138.745054  3087.81     43177.      ]
#  [  135.          35.36088    138.742157  3266.24     43499.      ]
#  [  136.          35.362555   138.739261  3434.59     43821.      ]
#  [  137.          35.36423    138.736364  3600.08     44143.      ]
#  [  138.          35.365904   138.733468  3679.96     44466.      ]
#  [  139.          35.367579   138.730571  3664.9      44788.      ]]

# %% [markdown]
# ### [Problem 1] Data visualization
#
# Visualize elevation data using Matplotlib. If you set "the number of the point" on the horizontal axis and "elevation" on the vertical axis, you can draw a cross-sectional view of Mt. Fuji.

# %%
plt.title("Mt. Fuji")
plt.xlabel("position")
plt.ylabel("elevation[m]")
plt.plot(fuji[:, 0], fuji[:, 3]) # Since the number of that point is a serial number from 0, it can be omitted (however, the number may be different, so it is specified as an example of the answer)
plt.show()

# %% [markdown]
# It will be easier to see if you put it in a variable as follows.

# %%
fuji_positions = fuji[:, 0]
fuji_elevations = fuji[:, 3]

plt.title("Mt. Fuji")
plt.xlabel("position")
plt.ylabel("elevation[m]")
plt.plot(fuji_positions, fuji_elevations)
plt.show()

# %% [markdown]
# ### [Problem 2] Create a function to calculate the gradient at a certain point
#
# In "Two-dimensional array and gradient problem", the gradient at each point was calculated first. However, if you imagine Mt. Fuji in the dark, you can only know the slope of your current location.
#
# Create a function to find the gradient by the relationship between "the number of the current point" and "the number of the next point you are now (number of the current point-1)".
#
# The gradient was calculated by the following formula, but in this data, "elevation" corresponds to y and "the number of that point" corresponds to x.
#
# <img src="gradient.png" size="200"/>
#
# (Commentary)
#
# Put the formula for the gradient into the code.

# %% [markdown]
# ### [Problem 3] Create a function to calculate the destination point
#
# Create a function that calculates the next point to move to based on the information on the slope of the current point.
#
# Expressed in a mathematical formula, ** "destination point = current point-$ \ alpha $ x current point gradient" **.
#
# For "Slope of the current point", use the return value of the function created in Problem 2. $ \ Alpha $ is a ** hyperparameter ** that takes any value greater than 0. In the field of machine learning, it is called the learning rate. The way of descending changes depending on this value. Here, for example, set it to 0.2.
#
# ** Implementation notes **
#
# When the above formula is calculated, a floating point number appears at the destination point, but this time the point must be represented by an integer in order to obtain the gradient information. Therefore, please perform conversion by rounding. In addition, it is necessary to take action when the value becomes unreliable. For example, if the destination point is negative, then no such data exists and the next gradient cannot be obtained.
#
# ** What are hyperparameters **
#
# It is a value that cannot be optimized by the machine learning method itself. The setting should be done carefully, as the value will change the behavior of the method and affect the success of the learning. The simplest way is to think and set it by humans, but there are also methods for mechanically determining hyperparameters.
#
# (Commentary)
#
# It is necessary to write the formula as it is as a program and then add some processing.
#
# > In order to obtain the gradient information this time, the points must be represented by integers. Therefore, please perform the conversion by rounding.
#
# You can use `np.round ()`.
#
# [numpy.round — NumPy v1.13 Manual](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.round_.html)
#
# >
# If the destination point is negative, then no such data exists and the next gradient cannot be obtained.
#
# There are many possible ways to implement this, but it is convenient to use `np.maximum ()` or `np.minimum ()`.
#
# [numpy.maximum — NumPy v1.16 Manual](https://docs.scipy.org/doc/numpy/reference/generated/numpy.maximum.html)
#
# [numpy.minimum — NumPy v1.16 Manual](https://docs.scipy.org/doc/numpy/reference/generated/numpy.minimum.html#numpy.minimum)
#
# Using NumPy functions makes processing more efficient and makes it easier to extend to array input.

# %% [markdown]
# ### [Problem 4] Create a function that goes down the mountain
#
# Create a function that goes down the mountain. Receive the first point and update the point with the function in question 3. Record the points for each move in a list, etc., and use this as the return value of the function.
#
# The first "current location" is the 136th location (elevation 3434.59 [m]) near the top of Mt. Fuji. Let's go down the mountain from here.
#
# ** Implementation notes **
#
# Since we are rounding off in question 3, the destination point may be the same as the current point. It means that the amount of movement has decreased, so please judge that you have gone down the mountain at that point. This does not happen with the actual gradient descent method.
#
# (Commentary)
#
# Write a while statement on the condition that the loop is exited when the destination point becomes the same as the current point.
#
# Considering this problem more developmentally, it is possible that we will continue to follow the same route. As a condition that includes all of these, "If you come to a point you have visited in the past, exit the loop".

# %% [markdown]
# ### [Problem 5] Visualization of the descent process
#
# Visualize the descending process in Problem 4 with a graph using Matplotlib.
#
# ** Visualization example **
#
# --Display the moved points in the cross section as dots
# --Make a line graph of altitude and slope for each repetition
#
# (Commentary)
#
# > Display the moved points in the cross section as dots
#
# Use `plt.scatter ()` to display as dots. By using the list created in Problem 4 for indexing like `fuji_elevations [descended_list]`, you can get a list of elevations in the descent process. By setting this to a value in the height direction, you can make dots.
#
# > Make a line graph of altitude and slope for each repetition
#
# Use `plt.plot ()` for line charts. This also makes a list of values ​​in the height direction.

# %%
fuji_elevations = fuji[:, 3]
descended_elevations = fuji_elevations[descended_list]

# Display the moved point as a point in the cross-sectional view.
plt.title('Downhill process of Mt. Fuji')
plt.ylabel('elevation[m]')
plt.xlabel('position')
plt.plot(fuji_elevations)
plt.scatter(descended_list, descended_elevations, 20, color='red')
plt.show()

# %%
fuji_elevations = fuji[:, 3]
descended_elevations = fuji_elevations[descended_list]

# Make a line graph of the elevation at each iteration.
plt.title('Downhill process of Mt. Fuji')
plt.ylabel('elevation[m]')
plt.xlabel('number of iterations')
plt.plot(descended_elevations)
plt.show()

# %% [markdown]
# ### [Problem 6] Change of initial value
#
#
# In Question 4, the first "where you are" is 136, but calculate this for all other points. Then, visualize what kind of descent process will occur for some initial values ​​as in Problem 5. In machine learning, it can be confirmed that how to set the ** initial value ** affects the result.
#
# ** What is the initial value **
#
# A value like the first point in this example is called the initial value. If you change this, the result will change. For example, 136 and 142 will go down different slopes of Mt. Fuji.
#
# (Commentary)
#
# While changing the initial value with the for statement, assign it to the list.
#
# If the function in Problem 4 corresponds to multiple initial values, it is possible to replace it with a calculation by NumPy instead of a for statement.

# %% [markdown]
# ### [Problem 7] (Advance problem) Hyperparameter change
#
# Visualize what kind of descent process will occur if you change the hyperparameter $ \ alpha $, as in Problem 5. And make sure that the hyperparameters make a big difference in the results.
#
# (Commentary)
#
# Rewrite the code in question 6 to apply to $ \ alpha $ instead of the initial value.
#
# You can easily draw multiple graphs by using the for statement when drawing the graph.
